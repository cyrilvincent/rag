# %%
#!pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\conta\git-cvc\formation\python\rag\git-rag\.venv\lib\site-packages (1.7.0)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\conta\git-cvc\formation\python\rag\git-rag\.venv\lib\site-packages (from scikit-learn) (2.1.3)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\conta\git-cvc\formation\python\rag\git-rag\.venv\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\conta\git-cvc\formation\python\rag\git-rag\.venv\lib\site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\conta\git-cvc\formation\python\rag\git-rag\.venv\lib\site-packages (from scikit-learn) (3.6.0)

# %%
import numpy as np
import sklearn.neighbors as nn
import matplotlib.pyplot as plt

# %%
with np.load("data/mnist/mnist.npz", allow_pickle=True) as f:
    xtrain, ytrain = f["x_train"], f["y_train"]
    xtest, ytest = f["x_test"], f["y_test"]
xtrain = xtrain[:10000]
ytrain = ytrain[:10000]
xtrain.shape, ytrain.shape
# Out:
# ((10000, 28, 28), (10000,))

# %%
plt.imshow(xtrain[0], cmap=plt.cm.gray_r)

# %%
xtrain = xtrain.reshape(-1, 28*28)
xtest = xtest.reshape(-1,28*28)
model = nn.KNeighborsClassifier(n_neighbors=3)
model.fit(xtrain, ytrain)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
ypredicted = model.predict(xtest)
score = model.score(xtest, ytest)
score
# Out:
# 0.9463

# %%
np.random.seed(0)
xtest = xtest.reshape(-1, 28, 28)
select = np.random.randint(xtest.shape[0], size=12)
for index, value in enumerate(select):
    plt.subplot(3, 4, index + 1)
    plt.axis("off")
    plt.imshow(xtest[value], cmap=plt.cm.gray_r)
    plt.title(f"Predicted {ypredicted[value]}")

# %%
errors = ytest != ypredicted
xerrors = xtest[errors]
yerrors = ypredicted[errors]
select = np.random.randint(xerrors.shape[0], size=12)
for index, value in enumerate(select):
    plt.subplot(3, 4, index + 1)
    plt.axis("off")
    plt.imshow(xerrors[value], cmap=plt.cm.gray_r)
    plt.title(f"Predicted {yerrors[value]}")
