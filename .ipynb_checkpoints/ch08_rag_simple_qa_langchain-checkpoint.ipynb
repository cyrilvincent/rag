# %%
import sys
# !{sys.executable} -m pip install langchain-text-splitters langgraph

# %%
import os
os.environ['USER_AGENT'] = 'Mozilla/5.0 (Windows NT 6.1; Win64; x64; rv:47.0) Gecko/20100101 Firefox/47.0'
import langchain
from langchain_openai import OpenAIEmbeddings
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_core.vectorstores import InMemoryVectorStore
from langchain import hub
from langchain_community.document_loaders import TextLoader
from langchain_core.documents import Document
from langchain.chains import RetrievalQA
langchain.__version__
# Out:
# '0.3.27'

# %%
with open("data/secrets/key.secret") as f:
    os.environ["OPENAI_API_KEY"] = f.read()

# %%
loader = TextLoader("data/books/cyril.txt")
docs = loader.load()
docs
# Out:
# [Document(metadata={'source': 'data/books/cyril.txt'}, page_content="Cyril Vincent est nÃ© le 15/11/1972\nIl est le papa d'Elisa et de Matis\n")]

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
all_splits = text_splitter.split_documents(docs)
all_splits
# Out:
# [Document(metadata={'source': 'data/books/cyril.txt'}, page_content="Cyril Vincent est nÃ© le 15/11/1972\nIl est le papa d'Elisa et de Matis")]

# %%
embeddings = OpenAIEmbeddings(model="text-embedding-3-large")
vector_store = InMemoryVectorStore(embeddings)
db = vector_store.add_documents(documents=all_splits)
db
# Out:
# ['958026dd-e7a0-4707-96c9-dcbd71cb9c8d']

# %%
retriever = vector_store.as_retriever(search_kwargs={"k": 3})
qa_chain = RetrievalQA.from_chain_type(llm=ChatOpenAI(), retriever=retriever)
qa_chain
# Out:
# RetrievalQA(verbose=False, combine_documents_chain=StuffDocumentsChain(verbose=False, llm_chain=LLMChain(verbose=False, prompt=ChatPromptTemplate(input_variables=['context', 'question'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=['context'], input_types={}, partial_variables={}, template="Use the following pieces of context to answer the user's question.\nIf you don't know the answer, just say that you don't know, don't try to make up an answer.\n----------------\n{context}"), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['question'], input_types={}, partial_variables={}, template='{question}'), additional_kwargs={})]), llm=ChatOpenAI(client=<openai.resources.chat.completions.completions.Completions object at 0x00000175C7CBFBD0>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x00000175C7CBF7D0>, root_client=<openai.OpenAI object at 0x00000175C7CBE110>, root_async_client=<openai.AsyncOpenAI object at 0x00000175C7CBDD90>, model_kwargs={}, openai_api_key=SecretStr('**********'), stream_usage=True), output_parser=StrOutputParser(), llm_kwargs={}), document_prompt=PromptTemplate(input_variables=['page_content'], input_types={}, partial_variables={}, template='{page_content}'), document_variable_name='context'), retriever=VectorStoreRetriever(tags=['InMemoryVectorStore', 'OpenAIEmbeddings'], vectorstore=<langchain_core.vectorstores.in_memory.InMemoryVectorStore object at 0x00000175C77F3350>, search_kwargs={'k': 3}))

# %%
query = "Quand est né Cyril et qui sont ses enfants ?"
response = qa_chain.invoke(query)
response
# Out:
# {'query': 'Quand est né Cyril et qui sont ses enfants ?', 'result': "Cyril Vincent est né le 15 novembre 1972 et il est le papa d'Elisa et de Matis."}
