# %%
# !pip install mistralai

# %%
import os
import mistralai
from mistralai import Mistral
mistralai.__version__
# Out:
# '1.8.2'

# %%
with open("data/secrets/mistral.secret") as f:
    os.environ["MISTRAL_API_KEY"] = f.read()
    api_key = os.environ["MISTRAL_API_KEY"]

# %%
client = Mistral(api_key=api_key)
chat_response = client.chat.complete(
    model= "mistral-large-latest",
    messages = [
        {
            "role": "user",
            "content": "What is the best French cheese?",
        },
    ]
)
chat_response.choices[0].message.content
# Out:
# The "best" French cheese is highly subjective—it depends on personal taste, texture preferences, and how you plan to enjoy it (on a cheese board, melted, in cooking, etc.). However, here are some of the most celebrated and iconic French cheeses, each with its own unique appeal:
#
# ### **Top Contenders for "Best" French Cheese**
# 1. **Comté** (AOP)
#    - **Why?** A versatile, nutty, and slightly sweet Alpine cheese with complex flavors that develop with age (from mild at 4–8 months to crystalline and caramelized at 24+ months).
#    - **Best for:** Cheese boards, fondue, grilled cheese, or eating plain.
#
# 2. **Roquefort** (AOP)
#    - **Why?** The "King of Blues"—creamy, tangy, and salty with a sharp finish, made from sheep’s milk and aged in natural caves.
#    - **Best for:** Spread on bread, in salads, or paired with Sauternes wine.
#
# 3. **Camembert de Normandie** (AOP)
#    - **Why?** The quintessential French cheese—creamy, buttery, and earthy with a bloomy rind. Legendary since Napoleon’s time.
#    - **Best for:** Baked (Camembert en croûte), with crusty bread, or apples.
#
# 4. **Époisses de Bourgogne** (AOP)
#    - **Why?** A pungent, washed-rind cheese with a luscious, almost liquid center. Napoleon reportedly loved it.
#    - **Best for:** Bold cheese lovers; pair with Burgundy wine or champagne.
#
# 5. **Reblochon** (AOP)
#    - **Why?** The star of **tartiflette**—creamy, nutty, and slightly fruity, with a soft, washable rind.
#    - **Best for:** Melting (tartiflette, croque-monsieur) or on a cheese plate.
#
# 6. **Brie de Meaux** (AOP)
#    - **Why?** The "Queen of Cheeses"—rich, buttery, and mushroomy, with a velvety texture. A favorite of French royalty.
#    - **Best for:** Eating at room temperature with baguette or fruit.
#
# 7. **Munster (Munster-Géromé)** (AOP)
#    - **Why?** A strong, pungent washed-rind cheese from Alsace, with a creamy, almost meaty flavor.
#    - **Best for:** Melting (in tarts or on potatoes) or with cumin and beer.
#
# 8. **Beaufort** (AOP)
#    - **Why?** A firmer Alpine cheese similar to Gruyère but richer and nuttier, often called the "Prince of Gruyères."
#    - **Best for:** Fondue, gratins, or shaving over salads.
#
# 9. **Chèvre (Goat Cheese) – Crottin de Chavignol, Valençay, or Sainte-Maure**
#    - **Why?** France’s goat cheeses range from fresh and tangy to aged and crumbly, with herbal notes.
#    - **Best for:** Salads, on toast, or baked (warm chèvre is divine).
#
# 10. **Bleu d’Auvergne**
#    - **Why?** A creamy, spicy blue cheese with a bold flavor but less salty than Roquefort.
#    - **Best for:** Dressings, burgers, or with pears and walnuts.
#
# ### **Honorable Mentions**
# - **Mimolette** (aged, nutty, and crumbly—like a French cheddar)
# - **Tomme de Savoie** (semi-firm, mild, and great for melting)
# - **Pélardon** (small, tangy goat cheese from the South)
# - **Livaro** (a Norman cheese similar to a milder Pont-l’Évêque)
#
# ### **How to Choose?**
# - **Mild & Creamy?** Brie de Meaux, Camembert, Saint-André.
# - **Bold & Pungent?** Époisses, Munster, Pont-l’Évêque.
# - **Nutty & Aged?** Comté, Beaufort, Mimolette.
# - **Blue Cheese Lover?** Roquefort, Bleu d’Auvergne.
# - **Goat Cheese Fan?** Crottin, Valençay, or fresh chèvre.
#
# ### **The Ultimate Answer?**
# If forced to pick **one** "best" cheese, **Comté** (aged 18–24 months) is often crowned for its balance of complexity, versatility, and widespread appeal. But the true joy of French cheese is in the **diversity**—so try them all!
#
# **Pro Tip:** Visit a **fromagerie** in France (like **Laurent Dubois** in Paris) for expert recommendations and tastings. And always serve cheese at **room temperature** for the best flavor!
#
# What’s your favorite way to enjoy French cheese? 🧀🇫🇷
