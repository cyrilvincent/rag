# %%
# !python -m pip install numpy matplotlib scipy
# Out:
# Requirement already satisfied: numpy in c:\users\conta\git-cvc\formation\python\rag\git-rag\.venv\lib\site-packages (2.1.3)
# Requirement already satisfied: matplotlib in c:\users\conta\git-cvc\formation\python\rag\git-rag\.venv\lib\site-packages (3.10.3)
# Requirement already satisfied: scipy in c:\users\conta\git-cvc\formation\python\rag\git-rag\.venv\lib\site-packages (1.15.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\conta\git-cvc\formation\python\rag\git-rag\.venv\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\conta\git-cvc\formation\python\rag\git-rag\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\conta\git-cvc\formation\python\rag\git-rag\.venv\lib\site-packages (from matplotlib) (4.58.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\conta\git-cvc\formation\python\rag\git-rag\.venv\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\conta\git-cvc\formation\python\rag\git-rag\.venv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\conta\git-cvc\formation\python\rag\git-rag\.venv\lib\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\conta\git-cvc\formation\python\rag\git-rag\.venv\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\conta\git-cvc\formation\python\rag\git-rag\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\conta\git-cvc\formation\python\rag\git-rag\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.fftpack import dct

# %%
O = np.array([0.,0])
A = np.array([1.,2])
B = np.array([3.,4])
O,A,B
# Out:
# (array([0., 0.]), array([1., 2.]), array([3., 4.]))

# %%
plt.arrow(O[0], O[1], A[0], A[1], color="blue", head_width=0.05, head_length=0.05, )
plt.arrow(O[0], O[1], B[0], B[1], color="red", head_width=0.05, head_length=0.05, )

# %%
euclid = np.sqrt((A[0]-B[0])**2+(A[1]-B[1])**2)
norm = np.linalg.norm(A-B)
euclid, norm
# Out:
# (np.float64(2.8284271247461903), np.float64(2.8284271247461903))

# %%
scalar = (A[0]**2+A[1]**2+B[0]**2+B[1]**2-((A[0]-B[0])**2+(A[1]-B[1])**2)) * 0.5
inner = np.inner(A,B)
dot = np.dot(A,B)
scalar, inner, dot
# Out:
# (np.float64(11.0), np.float64(11.0), np.float64(11.0))

# %%
dct(np.array(A))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 dct(np.array(A))
#
# NameError: name 'dct' is not defined
