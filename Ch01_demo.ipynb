# %% [markdown]
# To install
# ```
# pip install jupyterlab ipywidget
# jupyter lab
# ```

# %%
import sys
sys.version
# Out:
# '3.12.0 (tags/v3.12.0:0fb18b0, Oct  2 2023, 13:03:39) [MSC v.1935 64 bit (AMD64)]'

# %%
# !{sys.executable} -m pip install --upgrade pip
# !{sys.executable} -m pip install langchain langchain-community langchain-openai langchain-mistralai
# !{sys.executable} -m pip install openai
# Out:
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 1.8/1.8 MB 11.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 25.1.1
#     Uninstalling pip-25.1.1:
#       Successfully uninstalled pip-25.1.1
# ...
#   Using cached langchain_mistralai-0.2.12-py3-none-any.whl.metadata (2.0 kB)
# ...
# Using cached langchain_mistralai-0.2.12-py3-none-any.whl (16 kB)
# ...

# %%
import langchain
import openai
langchain.__version__, openai.__version__
# Out:
# ('0.3.27', '2.3.0')
