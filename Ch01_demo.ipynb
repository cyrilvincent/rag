# %% [markdown]
# To install
# ```
# pip install jupyterlab
# jupyter lab
# ```

# %%
import sys
sys.version
# Out:
# '3.11.3 (tags/v3.11.3:f3909b8, Apr  4 2023, 23:49:59) [MSC v.1934 64 bit (AMD64)]'

# %%
# !{sys.executable} -m pip install --upgrade pip
# !{sys.executable} -m pip install langchain langchain-community langchain-openai langchain-mistralai
# !{sys.executable} -m pip install openai
# Out:
# Requirement already satisfied: langchain in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (0.3.27)
# Requirement already satisfied: langchain-community in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (0.3.31)
# Requirement already satisfied: langchain-openai in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (0.3.35)
# Collecting langchain-mistralai
#   Downloading langchain_mistralai-0.2.12-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.72 in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (from langchain) (0.3.79)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (from langchain) (0.3.11)
# Requirement already satisfied: langsmith>=0.1.17 in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (from langchain) (0.4.36)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (from langchain) (2.12.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (from langchain) (1.4.29)
# Requirement already satisfied: requests<3,>=2 in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (from langchain) (2.32.5)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (from langchain) (6.0.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (8.2.3)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (1.33)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (4.15.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (25.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<1.0.0,>=0.3.72->langchain) (2.4)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (from langsmith>=0.1.17->langchain) (0.25.2)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (from langsmith>=0.1.17->langchain) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (from langsmith>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: anyio in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (4.1.0)
# Requirement already satisfied: certifi in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (2022.12.7)
# Requirement already satisfied: httpcore==1.* in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.0.2)
# Requirement already satisfied: idna in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (2.10)
# Requirement already satisfied: sniffio in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.4 in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2->langchain) (1.26.15)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (2.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (from langchain-community) (3.13.0)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (from langchain-community) (2.11.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.0.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: openai<3.0.0,>=1.104.2 in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (from langchain-openai) (2.3.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (from openai<3.0.0,>=1.104.2->langchain-openai) (1.8.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (from openai<3.0.0,>=1.104.2->langchain-openai) (0.11.0)
# Requirement already satisfied: tqdm>4 in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (from openai<3.0.0,>=1.104.2->langchain-openai) (4.66.1)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2023.10.3)
# Collecting tokenizers<1,>=0.15.1 (from langchain-mistralai)
#   Downloading tokenizers-0.22.1-cp39-abi3-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (from tokenizers<1,>=0.15.1->langchain-mistralai) (0.19.4)
# Requirement already satisfied: filelock in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15.1->langchain-mistralai) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15.1->langchain-mistralai) (2023.12.1)
# Requirement already satisfied: colorama in c:\users\conta\appdata\local\programs\python\python311\lib\site-packages (from tqdm>4->openai<3.0.0,>=1.104.2->langchain-openai) (0.4.6)
# Downloading langchain_mistralai-0.2.12-py3-none-any.whl (16 kB)
# Downloading tokenizers-0.22.1-cp39-abi3-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    --------------- ------------------------ 1.0/2.7 MB 10.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 12.9 MB/s  0:00:00
# Installing collected packages: tokenizers, langchain-mistralai
#
#   Attempting uninstall: tokenizers
#
#     Found existing installation: tokenizers 0.15.0
#
#     Uninstalling tokenizers-0.15.0:
#
#       Successfully uninstalled tokenizers-0.15.0
#
#    ---------------------------------------- 0/2 [tokenizers]
#    ---------------------------------------- 0/2 [tokenizers]
#    ---------------------------------------- 0/2 [tokenizers]
#    ---------------------------------------- 0/2 [tokenizers]
#    ---------------------------------------- 0/2 [tokenizers]
#    ---------------------------------------- 0/2 [tokenizers]
#    ---------------------------------------- 0/2 [tokenizers]
#    ---------------------------------------- 0/2 [tokenizers]
#    ---------------------------------------- 0/2 [tokenizers]
#    ---------------------------------------- 0/2 [tokenizers]
#    ---------------------------------------- 0/2 [tokenizers]
#    ---------------------------------------- 0/2 [tokenizers]
#    ---------------------------------------- 0/2 [tokenizers]
#    ---------------------------------------- 0/2 [tokenizers]
#    ---------------------------------------- 0/2 [tokenizers]
#    ---------------------------------------- 0/2 [tokenizers]
#    ---------------------------------------- 0/2 [tokenizers]
#    ---------------------------------------- 0/2 [tokenizers]
#    ---------------------------------------- 0/2 [tokenizers]
#    ---------------------------------------- 2/2 [langchain-mistralai]
#
# Successfully installed langchain-mistralai-0.2.12 tokenizers-0.22.1
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\conta\AppData\Local\Programs\Python\Python311\Lib\site-packages\~okenizers'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# transformers 4.36.0 requires tokenizers<0.19,>=0.14, but you have tokenizers 0.22.1 which is incompatible.

# %%
import langchain
import openai
langchain.__version__, openai.__version__
# Out:
# ('0.3.27', '1.3.8')
